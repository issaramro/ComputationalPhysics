# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

l= np.arange(1000, 5000, 10)
z = np.zeros(len(l))
a = 2355.9
b = 2.12*10**(-4)
B =(l*np.exp(a/l) - l)*b - 1
plt.plot(l,B)
plt.plot(l,z)
plt.show()

def Newton_Method(f, df,a,b, p, k):
    r= np.zeros(k)
    root = 0
    # 2 bisections first
    r[0] = (a+b)/2
    if f(a)*f(r[0]) < 0:
        r[1] = (a + r[0])/2
    elif f(b)*f(r[0]) < 0:
        r[1]= (r[0] + b)/2
    else:
        root = r[0]
        return
    # Newton method
    n = 1
    tol = 0.5 * 10**(-p + 1)
    error = tol + 1
    while (error > tol and n <k-1):
       r[n+1] = r[n] - f(r[n])/df(r[n])
       error = np.abs((r[n+1] - r[n])/ r[n+1])
       n = n+1
    if n > k:
        print("no convergence")
    else:
        root = r[len(r) -1]
    return root

def f(x):
    a = 2355.9
    b = 2.12*10**(-4)
    return (x*np.exp(a/x) - x)*b - 1
def df(x):
    a = 2355.9
    b = 2.12*10**(-4)
    return (np.exp(a/x) - (a/x)*np.exp(a/x) -1)*b

print(Newton_Method(f, df, 1800, 2100, 2000, 1000))
# Out:
# 1872.3528267512675
